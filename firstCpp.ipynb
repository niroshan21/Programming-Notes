// %% [markdown]
// # C++ Note
//
// #### Code Structure

// %%
#include <iostream>
using namespace std;

// %% [markdown]
// int main(){
//
//     Your code goes to here.
//
//     return 0;
// }

// %%
cout<<"Hello World!!"<<" "; 
cout<<"Let's start to learn C++.";   
//There is no new line.
// Out:
// Hello World!! Let's start to learn C++.
// @0x7f7b45f30de0

// %%
//If we want new line. We can use :-  endl

cout<<"Hello World!!"<<endl; 
cout<<"Let's start to learn C++.";
// Out:
// Hello World!!
// Let's start to learn C++.

// %%
/* This is a multi line comment.
This is a multi line comment.
This is a multi line comment. */

// %% [markdown]
// #### Variables

// %%
int    myNum      = 5    ;
double myFloatNum = 4.58 ;
char   myLetter   = 'G'  ;                  // 'D' 'h' character
string myText     = "Rajitha Niroshan";
bool   myBool     = true ;

// %% [markdown]
// #### Declaring multiple variables.

// %%
int a = 4, b = 5, c = 6 ;

cout<<a<<" "<<b<<" "<<c ;
// Out:
// 4 5 6

// %%
int x ;
int m,n,k ;

x = 4;
m = 5;

// %% [markdown]
// #### Constants
// They are always be a constant number. They cannot change.

// %%
const int myNum = 41 ;
cout<<myNum;
// Out:
// 41

// %%
myNum = 78 ;   // Thre will be a error. Because we can't change constant number.
// Out:
// input_line_54:2:8: error: cannot assign to variable 'myNum' with const-qualified type 'const int'
//  myNum = 78 ;
//  ~~~~~ ^
// input_line_53:2:12: note: variable 'myNum' declared const here
//  const int myNum = 41 ;
//  ~~~~~~~~~~^~~~~~~~~~
// Interpreter Error:

// %%
cout<<  sizeof(myNum);  // Returns the size of an object in bytes.
// Out:
// 4
// @0x7f7b45f30de0

// %% [markdown]
// #### User Input

// %%
int x ;
cin>> x ;  //Get user input.
// Out:
// 568
// @0x7f7b45f30f00

// %% [markdown]
// ### Arithmatic
// #### include  [cmath]

// %%
# include <cmath>
